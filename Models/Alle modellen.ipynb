# %% [markdown]
# <h1>Victuz Machine learning PI6</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

eventdf = pd.read_csv("evenementinformatie.csv",sep=';')
berichtdf = pd.read_csv("berichtinteracties_met_sentiment.csv",sep=';')
evenentuserdf = pd.read_csv("evenementaanwezigheid.csv",sep=';')
userdf = pd.read_csv("gebruikersinformatie.csv",sep=';')

# %%
objs = [berichtdf, userdf]


df = pd.concat(objs, axis=0) #mergen van users en userberichten

# %%
df
# Out:
#     BerichtID BerichtDatum GebruikerID EvenementID BerichtSentiment  \
# 0        B001    18-5-2023        G309        E012         Neutraal
# 1        B002    6-10-2023        G021        E039         Positief
# 2        B003     7-7-2023        G111        E001         Positief
# 3        B004    5-10-2023        G168        E015         Negatief
# 4        B005    22-1-2023        G076        E017         Neutraal
# ..        ...          ...         ...         ...              ...
# 315       NaN          NaN        G316         NaN              NaN
# 316       NaN          NaN        G317         NaN              NaN
# 317       NaN          NaN        G318         NaN              NaN
# 318       NaN          NaN        G319         NaN              NaN
# 319       NaN          NaN        G320         NaN              NaN
#
#      OntvangenLikes  OntvangenReacties RegistratieDatum LaatsteLogin  \
# 0               5.0                8.0              NaN          NaN
# ...

# %%
compare = [df["GebruikerID"].count(), df["BerichtID"].count()]
labels = ["GebruikerID", "BerichtID"]

# Create the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=labels, y=compare)
plt.ylabel("Count")
plt.title("Comparison of GebruikerID and BerichtID Counts")
plt.show()
